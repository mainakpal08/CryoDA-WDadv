# %%
from __future__ import print_function
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from numpy.random import randint
import math
from torch.nn import functional as F
import numpy as np
import time
import pdb
from torch.autograd import grad
import copy
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

import utils
import models

# %%
class opt:
    source_train_path = '/datasets/snr003/SNR003_train.h5'
    source_test_path = '/datasets/snr003/SNR003_test.h5'
    target_train_path = '/datasets/snr005/SNR005_train.h5'
    target_test_path = '/datasets/snr005/SNR005_test.h5'
    numclass = 10
    fet_size = 128
    h = 400
    nepoch = 100
    nepoch_wdgrl = 50
    cuda = True
    manualSeed = 9182
    batch_size = 32
    tomo_dim = (32,32,32)
    clfr_lr = 0.0001
    critic_iter = 1
    clfr_iter = 1
    gamma = 10
    wd_clf = 1
    save_src_clfr = "./best_model/source_clfr_snr003.pt"
    save_tar_clfr = "./best_model/target_clfr_005_from_003.pt"

# %%
if opt.manualSeed is None:
    opt.manualSeed = random.randint(1, 10000)
print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
if opt.cuda:
    torch.cuda.manual_seed_all(opt.manualSeed)

cudnn.benchmark = True

if torch.cuda.is_available() and not opt.cuda:
    print("WARNING: You have a CUDA device, so you should probably run with --cuda")
# Out:
# Random Seed:  9182

# %%
data = utils.DATA_LOADER(opt)
print("# of source training samples: ", data.source_ntrain)
print("# of source test samples: ", data.source_ntest)
print("# of target training samples: ", data.target_ntrain)
print("# of target test samples: ", data.target_ntest)
print("# of class: ", data.numclass)
# Out:
# # of source training samples:  4500
# # of source test samples:  500
# # of target training samples:  4500
# # of target test samples:  500
# # of class:  10

# %%
source_clsfr = models.CLFR(opt)
print(source_clsfr)
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
cls_criterion = nn.CrossEntropyLoss()
input_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])
input_label = torch.FloatTensor(opt.batch_size)

# %%
if opt.cuda :
    source_clsfr.cuda()
    cls_criterion.cuda()
    input_tomo = input_tomo.cuda()
    input_label = input_label.cuda()

# %%
def sample():
    batch_tomo, batch_label = data.source_next_batch(opt.batch_size)
    input_tomo.copy_(batch_tomo)
    input_label.copy_(batch_label)

# %%
optim_clfr = optim.Adam(source_clsfr.parameters(), lr=opt.clfr_lr)

# %%
def calculate_accuracy(net, tomo, label):
    utils.set_requires_grad(net, requires_grad=False)
    logits = net(tomo.cuda())
    _, predicted = torch.max(logits, 1)
    c = (predicted == label.cuda()).sum()
    c = c.cpu().numpy()
    acc = c / len(label)

    return acc

# %%
best_acc = 0

for epoch in range(opt.nepoch):
    for i in range(0, data.source_ntrain, opt.batch_size):

        for p in source_clsfr.parameters():
            p.requires_grad = True

        sample()
        source_clsfr.zero_grad()
        input_tomoV = Variable(input_tomo)
        input_labelV = Variable(input_label.long())

        logits = source_clsfr(input_tomoV)
        loss = cls_criterion(logits, input_labelV)
        loss.backward()
        optim_clfr.step()

    source_clsfr.eval()
    acc = calculate_accuracy(net=source_clsfr, tomo=data.source_test_subtom, label=data.source_test_label)
    print('[%d/%d] clfr_loss: %.4f | test_acc: %.4f'% (epoch, opt.nepoch, loss.item(),acc))

    if acc >= best_acc:
        print('[Source Domain]Validation Acc increased ({:.4f} --> {:.4f}).  Saving model ...'.format(best_acc,acc))
        torch.save(source_clsfr.state_dict(), opt.save_src_clfr)
        best_acc = acc

    source_clsfr.train()
# Out:
# [0/100] clfr_loss: 2.1709 | test_acc: 0.1840
# [Source Domain]Validation Acc increased (0.0000 --> 0.1840).  Saving model ...
# [1/100] clfr_loss: 1.7075 | test_acc: 0.3800
# [Source Domain]Validation Acc increased (0.1840 --> 0.3800).  Saving model ...
# [2/100] clfr_loss: 1.3262 | test_acc: 0.6240
# [Source Domain]Validation Acc increased (0.3800 --> 0.6240).  Saving model ...
# [3/100] clfr_loss: 0.8770 | test_acc: 0.6640
# [Source Domain]Validation Acc increased (0.6240 --> 0.6640).  Saving model ...
# [4/100] clfr_loss: 0.9169 | test_acc: 0.7220
# [Source Domain]Validation Acc increased (0.6640 --> 0.7220).  Saving model ...
# [5/100] clfr_loss: 0.6135 | test_acc: 0.7360
# [Source Domain]Validation Acc increased (0.7220 --> 0.7360).  Saving model ...
# [6/100] clfr_loss: 0.2273 | test_acc: 0.7700
# [Source Domain]Validation Acc increased (0.7360 --> 0.7700).  Saving model ...
# [7/100] clfr_loss: 0.2630 | test_acc: 0.7680
# [8/100] clfr_loss: 0.3167 | test_acc: 0.7680
# [9/100] clfr_loss: 0.4121 | test_acc: 0.7800
# [Source Domain]Validation Acc increased (0.7700 --> 0.7800).  Saving model ...
# [10/100] clfr_loss: 0.4063 | test_acc: 0.7780
# [11/100] clfr_loss: 0.2698 | test_acc: 0.7800
# [Source Domain]Validation Acc increased (0.7800 --> 0.7800).  Saving model ...
# [12/100] clfr_loss: 0.8683 | test_acc: 0.7920
# [Source Domain]Validation Acc increased (0.7800 --> 0.7920).  Saving model ...
# [13/100] clfr_loss: 0.2524 | test_acc: 0.8100
# [Source Domain]Validation Acc increased (0.7920 --> 0.8100).  Saving model ...
# [14/100] clfr_loss: 0.1684 | test_acc: 0.8040
# [15/100] clfr_loss: 0.1006 | test_acc: 0.8160
# [Source Domain]Validation Acc increased (0.8100 --> 0.8160).  Saving model ...
# [16/100] clfr_loss: 0.0854 | test_acc: 0.7620
# [17/100] clfr_loss: 0.0724 | test_acc: 0.7840
# [18/100] clfr_loss: 0.0248 | test_acc: 0.7940
# [19/100] clfr_loss: 0.0584 | test_acc: 0.8080
# [20/100] clfr_loss: 0.0565 | test_acc: 0.8100
# [21/100] clfr_loss: 0.0315 | test_acc: 0.7960
# [22/100] clfr_loss: 0.0580 | test_acc: 0.8180
# [Source Domain]Validation Acc increased (0.8160 --> 0.8180).  Saving model ...
# [23/100] clfr_loss: 0.0181 | test_acc: 0.8080
# [24/100] clfr_loss: 0.0165 | test_acc: 0.8160
# [25/100] clfr_loss: 0.0037 | test_acc: 0.8300
# [Source Domain]Validation Acc increased (0.8180 --> 0.8300).  Saving model ...
# [26/100] clfr_loss: 0.0189 | test_acc: 0.7780
# [27/100] clfr_loss: 0.0456 | test_acc: 0.7960
# [28/100] clfr_loss: 0.0125 | test_acc: 0.8160
# [29/100] clfr_loss: 0.0242 | test_acc: 0.8040
# [30/100] clfr_loss: 0.0178 | test_acc: 0.8000
# [31/100] clfr_loss: 0.1006 | test_acc: 0.8040
# [32/100] clfr_loss: 0.0127 | test_acc: 0.8020
# [33/100] clfr_loss: 0.1559 | test_acc: 0.7880
# [34/100] clfr_loss: 0.0266 | test_acc: 0.8140
# [35/100] clfr_loss: 0.0026 | test_acc: 0.8200
# [36/100] clfr_loss: 0.0050 | test_acc: 0.8060
# [37/100] clfr_loss: 0.0093 | test_acc: 0.8060
# [38/100] clfr_loss: 0.0040 | test_acc: 0.7940
# [39/100] clfr_loss: 0.0165 | test_acc: 0.8240
# [40/100] clfr_loss: 0.0454 | test_acc: 0.8200
# [41/100] clfr_loss: 0.0109 | test_acc: 0.8200
# [42/100] clfr_loss: 0.0151 | test_acc: 0.8080
# [43/100] clfr_loss: 0.0085 | test_acc: 0.8240
# [44/100] clfr_loss: 0.0217 | test_acc: 0.8140
# [45/100] clfr_loss: 0.0099 | test_acc: 0.8240
# [46/100] clfr_loss: 0.0175 | test_acc: 0.7880
# [47/100] clfr_loss: 0.0011 | test_acc: 0.8200
# [48/100] clfr_loss: 0.0011 | test_acc: 0.8120
# [49/100] clfr_loss: 0.0036 | test_acc: 0.8220
# [50/100] clfr_loss: 0.0050 | test_acc: 0.8160
# [51/100] clfr_loss: 0.0178 | test_acc: 0.8100
# [52/100] clfr_loss: 0.0008 | test_acc: 0.8100
# [53/100] clfr_loss: 0.0033 | test_acc: 0.8180
# [54/100] clfr_loss: 0.0170 | test_acc: 0.8060
# [55/100] clfr_loss: 0.1170 | test_acc: 0.7980
# [56/100] clfr_loss: 0.0092 | test_acc: 0.8140
# [57/100] clfr_loss: 0.0105 | test_acc: 0.8220
# [58/100] clfr_loss: 0.0003 | test_acc: 0.8240
# [59/100] clfr_loss: 0.0071 | test_acc: 0.8240
# [60/100] clfr_loss: 0.0026 | test_acc: 0.8080
# [61/100] clfr_loss: 0.0096 | test_acc: 0.7760
# [62/100] clfr_loss: 0.0249 | test_acc: 0.8080
# [63/100] clfr_loss: 0.0009 | test_acc: 0.8120
# [64/100] clfr_loss: 0.0008 | test_acc: 0.8060
# [65/100] clfr_loss: 0.0012 | test_acc: 0.8060
# [66/100] clfr_loss: 0.1250 | test_acc: 0.8280
# [67/100] clfr_loss: 0.0038 | test_acc: 0.8160
# [68/100] clfr_loss: 0.0089 | test_acc: 0.8060
# [69/100] clfr_loss: 0.0014 | test_acc: 0.8060
# [70/100] clfr_loss: 0.0242 | test_acc: 0.8200
# [71/100] clfr_loss: 0.0036 | test_acc: 0.8180
# [72/100] clfr_loss: 0.0201 | test_acc: 0.8120
# [73/100] clfr_loss: 0.0038 | test_acc: 0.8300
# [Source Domain]Validation Acc increased (0.8300 --> 0.8300).  Saving model ...
# [74/100] clfr_loss: 0.0470 | test_acc: 0.7920
# [75/100] clfr_loss: 0.0037 | test_acc: 0.8100
# [76/100] clfr_loss: 0.0061 | test_acc: 0.8080
# [77/100] clfr_loss: 0.0009 | test_acc: 0.8160
# [78/100] clfr_loss: 0.0145 | test_acc: 0.8260
# [79/100] clfr_loss: 0.0044 | test_acc: 0.7920
# [80/100] clfr_loss: 0.0011 | test_acc: 0.8060
# [81/100] clfr_loss: 0.0029 | test_acc: 0.8080
# [82/100] clfr_loss: 0.2912 | test_acc: 0.7740
# [83/100] clfr_loss: 0.0001 | test_acc: 0.8140
# [84/100] clfr_loss: 0.0029 | test_acc: 0.8060
# [85/100] clfr_loss: 0.0458 | test_acc: 0.8040
# [86/100] clfr_loss: 0.0007 | test_acc: 0.8280
# [87/100] clfr_loss: 0.0019 | test_acc: 0.8160
# [88/100] clfr_loss: 0.0197 | test_acc: 0.8240
# [89/100] clfr_loss: 0.0632 | test_acc: 0.8180
# [90/100] clfr_loss: 0.0249 | test_acc: 0.7940
# [91/100] clfr_loss: 0.0001 | test_acc: 0.8120
# [92/100] clfr_loss: 0.0015 | test_acc: 0.8380
# [Source Domain]Validation Acc increased (0.8300 --> 0.8380).  Saving model ...
# [93/100] clfr_loss: 0.0002 | test_acc: 0.8140
# [94/100] clfr_loss: 0.0002 | test_acc: 0.8340
# [95/100] clfr_loss: 0.0001 | test_acc: 0.8380
# [Source Domain]Validation Acc increased (0.8380 --> 0.8380).  Saving model ...
# [96/100] clfr_loss: 0.0000 | test_acc: 0.8360
# [97/100] clfr_loss: 0.0001 | test_acc: 0.8420
# [Source Domain]Validation Acc increased (0.8380 --> 0.8420).  Saving model ...
# [98/100] clfr_loss: 0.0006 | test_acc: 0.8100
# [99/100] clfr_loss: 0.0073 | test_acc: 0.8220

# %%
target_clsfr = models.CLFR(opt)
target_clsfr.load_state_dict(torch.load(opt.save_src_clfr))
# Out:
# <All keys matched successfully>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def gradient_penalty(critic, h_s, h_t):
    # based on: https://github.com/caogang/wgan-gp/blob/master/gan_cifar10.py#L116
    alpha = torch.rand(h_s.size(0), 1).to(device)
    differences = h_t - h_s
    interpolates = h_s + (alpha * differences)
    interpolates = torch.stack([interpolates, h_s, h_t]).requires_grad_()

    preds = critic(interpolates)
    gradients = grad(preds, interpolates,
                     grad_outputs=torch.ones_like(preds),
                     retain_graph=True, create_graph=True)[0]
    gradient_norm = gradients.norm(2, dim=1)
    gradient_penalty = ((gradient_norm - 1)**2).mean()
    return gradient_penalty

# %%
critic = models.CRITIC(opt)
print(critic)
# Out:
# CRITIC(
#   (critic_block): Sequential(
#     (0): Linear(in_features=128, out_features=50, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
critic_optim = torch.optim.Adam(critic.parameters(), lr=1e-4)
clf_optim = torch.optim.Adam(target_clsfr.parameters(), lr=opt.clfr_lr)

# %%
clf_criterion = nn.CrossEntropyLoss()
source_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])
source_label = torch.FloatTensor(opt.batch_size)
target_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])

# %%
if opt.cuda :
    critic.cuda()
    target_clsfr.cuda()
    clf_criterion.cuda()
    source_tomo = source_tomo.cuda()
    source_label = source_label.cuda()
    target_tomo = target_tomo.cuda()

# %%
def both_sample():
    source_batch_tomo, source_batch_label = data.source_next_batch(opt.batch_size)
    source_tomo.copy_(source_batch_tomo)
    source_label.copy_(source_batch_label)
    target_batch_tomo, _ = data.target_next_batch(opt.batch_size)
    target_tomo.copy_(target_batch_tomo)

# %%
best_acc = 0

for epoch in range(opt.nepoch_wdgrl):
    for i in range(0, data.source_ntrain, opt.batch_size):
        both_sample()

        #train critic
        utils.set_requires_grad(critic, requires_grad=True)
        utils.set_requires_grad(target_clsfr, requires_grad=False)

        with torch.no_grad():
            h_s = target_clsfr.feature_extractor(source_tomo)
            h_t = target_clsfr.feature_extractor(target_tomo)
        
        for _ in range(opt.critic_iter):
            gp = gradient_penalty(critic, h_s, h_t)
            critic_s = critic(h_s)
            critic_t = critic(h_t)
            wasserstein_distance = critic_s.mean() - critic_t.mean()
            critic_cost = -wasserstein_distance + opt.gamma*gp

            critic_optim.zero_grad()
            critic_cost.backward()
            critic_optim.step()

        #train classifier
        utils.set_requires_grad(critic, requires_grad=False)
        utils.set_requires_grad(target_clsfr, requires_grad=True)

        for _ in range(opt.clfr_iter):
            source_features = target_clsfr.feature_extractor(source_tomo)
            target_features = target_clsfr.feature_extractor(target_tomo)

            source_preds = target_clsfr.classify(source_features)
            clf_loss = clf_criterion(source_preds, source_label.long())

            w_dist = critic(source_features).mean() - critic(target_features).mean()
            loss = clf_loss + opt.wd_clf*w_dist

            clf_optim.zero_grad()
            loss.backward()
            clf_optim.step()

    target_clsfr.eval()

    target_batch_tomo, target_batch_label = data.target_next_batch(100)
    tar_acc = calculate_accuracy(net=target_clsfr, tomo=target_batch_tomo, label=target_batch_label)

    print('[%d/%d] critic_cost: %.4f | w_dist: %.4f | clf_loss: %.4f | tar_acc: %.4f'% (epoch, opt.nepoch_wdgrl, critic_cost.item(), wasserstein_distance.item(), loss.item(), tar_acc))

    if tar_acc >= best_acc:
        print('[Target Domain]Validation Acc increased ({:.4f} --> {:.4f}).  Saving model ...'.format(best_acc,tar_acc))
        torch.save(target_clsfr.state_dict(), opt.save_tar_clfr)
        best_acc = tar_acc

    target_clsfr.train()
# Out:
# [0/50] critic_cost: 10.4625 | w_dist: -2.1330 | clf_loss: -1.2680 | tar_acc: 0.7600
# [Target Domain]Validation Acc increased (0.0000 --> 0.7600).  Saving model ...
# [1/50] critic_cost: 10.8994 | w_dist: -1.8958 | clf_loss: -1.5254 | tar_acc: 0.7700
# [Target Domain]Validation Acc increased (0.7600 --> 0.7700).  Saving model ...
# [2/50] critic_cost: 10.8036 | w_dist: -1.3188 | clf_loss: -1.1973 | tar_acc: 0.7600
# [3/50] critic_cost: 11.0891 | w_dist: -1.5567 | clf_loss: -1.5335 | tar_acc: 0.8400
# [Target Domain]Validation Acc increased (0.7700 --> 0.8400).  Saving model ...
# [4/50] critic_cost: 9.8088 | w_dist: -0.3293 | clf_loss: -0.0971 | tar_acc: 0.8800
# [Target Domain]Validation Acc increased (0.8400 --> 0.8800).  Saving model ...
# [5/50] critic_cost: 9.5257 | w_dist: -0.1242 | clf_loss: -0.1178 | tar_acc: 0.8500
# [6/50] critic_cost: 9.4721 | w_dist: -0.1015 | clf_loss: -0.0427 | tar_acc: 0.8600
# [7/50] critic_cost: 9.0850 | w_dist: 0.2389 | clf_loss: 0.2638 | tar_acc: 0.7900
# [8/50] critic_cost: 9.2405 | w_dist: -0.0243 | clf_loss: -0.0016 | tar_acc: 0.8200
# [9/50] critic_cost: 8.5534 | w_dist: 0.1657 | clf_loss: 0.2860 | tar_acc: 0.8000
# [10/50] critic_cost: 6.2478 | w_dist: 1.8231 | clf_loss: 1.9684 | tar_acc: 0.7500
# [11/50] critic_cost: 5.1374 | w_dist: 2.8601 | clf_loss: 3.1744 | tar_acc: 0.7600
# [12/50] critic_cost: 10.7676 | w_dist: -2.1723 | clf_loss: -0.7831 | tar_acc: 0.8200
# [13/50] critic_cost: 11.6236 | w_dist: -2.5113 | clf_loss: 2.3935 | tar_acc: 0.8100
# [14/50] critic_cost: 8.4500 | w_dist: 0.7199 | clf_loss: 0.7406 | tar_acc: 0.8700
# [15/50] critic_cost: 11.1286 | w_dist: -2.0750 | clf_loss: -2.0570 | tar_acc: 0.8400
# [16/50] critic_cost: 10.8417 | w_dist: -1.8690 | clf_loss: -1.7910 | tar_acc: 0.8600
# [17/50] critic_cost: 11.6683 | w_dist: -2.7368 | clf_loss: -2.7073 | tar_acc: 0.8800
# [Target Domain]Validation Acc increased (0.8800 --> 0.8800).  Saving model ...
# [18/50] critic_cost: 8.7978 | w_dist: 0.3821 | clf_loss: 1.2961 | tar_acc: 0.7000
# [19/50] critic_cost: 10.4422 | w_dist: -1.1027 | clf_loss: 0.9869 | tar_acc: 0.8600
# [20/50] critic_cost: 11.9961 | w_dist: -2.7295 | clf_loss: -2.4142 | tar_acc: 0.8300
# [21/50] critic_cost: 9.1979 | w_dist: 0.1476 | clf_loss: 0.4955 | tar_acc: 0.8500
# [22/50] critic_cost: 9.4938 | w_dist: -0.0468 | clf_loss: 0.5095 | tar_acc: 0.7700
# [23/50] critic_cost: 10.5076 | w_dist: -1.0289 | clf_loss: -0.1894 | tar_acc: 0.8200
# [24/50] critic_cost: 9.6971 | w_dist: -0.2666 | clf_loss: 0.8775 | tar_acc: 0.8400
# [25/50] critic_cost: 12.7781 | w_dist: -3.3418 | clf_loss: -3.0140 | tar_acc: 0.8300
# [26/50] critic_cost: 12.0398 | w_dist: -2.6518 | clf_loss: -2.3774 | tar_acc: 0.7400
# [27/50] critic_cost: 9.2736 | w_dist: 0.1142 | clf_loss: 0.3627 | tar_acc: 0.8400
# [28/50] critic_cost: 12.7785 | w_dist: -3.3651 | clf_loss: -2.7896 | tar_acc: 0.7700
# [29/50] critic_cost: 4.7686 | w_dist: 4.6270 | clf_loss: 5.8462 | tar_acc: 0.8500
# [30/50] critic_cost: 17.1750 | w_dist: -7.8005 | clf_loss: -7.1485 | tar_acc: 0.8400
# [31/50] critic_cost: 12.6559 | w_dist: -3.3095 | clf_loss: -1.6695 | tar_acc: 0.8000
# [32/50] critic_cost: 9.5596 | w_dist: -0.0225 | clf_loss: 1.2434 | tar_acc: 0.7500
# [33/50] critic_cost: 14.0190 | w_dist: -4.4419 | clf_loss: -3.6642 | tar_acc: 0.7500
# [34/50] critic_cost: 13.0731 | w_dist: -3.4965 | clf_loss: -2.7292 | tar_acc: 0.8300
# [35/50] critic_cost: 8.9333 | w_dist: 0.6986 | clf_loss: 2.3289 | tar_acc: 0.7900
# [36/50] critic_cost: 7.4527 | w_dist: 2.0575 | clf_loss: 3.3654 | tar_acc: 0.8100
# [37/50] critic_cost: 8.8707 | w_dist: 0.8116 | clf_loss: 2.2178 | tar_acc: 0.6800
# [38/50] critic_cost: 9.1076 | w_dist: 0.5495 | clf_loss: 2.2419 | tar_acc: 0.7400
# [39/50] critic_cost: 16.5978 | w_dist: -6.9632 | clf_loss: -6.4898 | tar_acc: 0.7100
# [40/50] critic_cost: 8.0582 | w_dist: 1.6354 | clf_loss: 2.8032 | tar_acc: 0.6800
# [41/50] critic_cost: 2.7232 | w_dist: 6.9363 | clf_loss: 7.9523 | tar_acc: 0.6100
# [42/50] critic_cost: 8.8552 | w_dist: 0.7922 | clf_loss: 2.0214 | tar_acc: 0.8200
# [43/50] critic_cost: 14.2659 | w_dist: -4.6303 | clf_loss: -3.8346 | tar_acc: 0.7600
# [44/50] critic_cost: 18.9762 | w_dist: -9.3351 | clf_loss: -8.3676 | tar_acc: 0.6200
# [45/50] critic_cost: 20.6917 | w_dist: -11.0542 | clf_loss: -8.6526 | tar_acc: 0.5100
# [46/50] critic_cost: 7.2785 | w_dist: 2.3374 | clf_loss: 3.9356 | tar_acc: 0.6600
# [47/50] critic_cost: 29.0860 | w_dist: -19.4272 | clf_loss: -17.1014 | tar_acc: 0.3600
# [48/50] critic_cost: 30.4631 | w_dist: -20.8040 | clf_loss: -14.9529 | tar_acc: 0.1300
# [49/50] critic_cost: 15.1862 | w_dist: -5.5475 | clf_loss: -2.7458 | tar_acc: 0.0600

# %%
target_clsfr = models.CLFR(opt)
target_clsfr.load_state_dict(torch.load(opt.save_tar_clfr))
target_clsfr.cuda()
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
target_clsfr.eval()
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
utils.set_requires_grad(target_clsfr, requires_grad=False)
acc = calculate_accuracy(net=target_clsfr, tomo=data.target_train_subtom, label=data.target_train_label)
acc
# Out:
# 0.8211111111111111

# %%
utils.set_requires_grad(target_clsfr, requires_grad=False)
logits = target_clsfr(data.target_train_subtom.cuda())
_, predicted = torch.max(logits, 1)

# %%
ground_truth = data.target_train_label
pred = predicted.cpu().numpy()

# %%
conf_mat = confusion_matrix(ground_truth, pred)

# %%
tomo_class = ['1bxn', '1f1b', '1yg6', '2byu', '2h12', '2ldb', '3gl1', '3hhb', '4d4r', '6t3e']

# %%
df_cm = pd.DataFrame(conf_mat, index = [i for i in tomo_class],
                  columns = [i for i in tomo_class])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10},fmt="d", cmap="magma_r")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Target: SNR 0.05 | Source: SNR 0.03 | WDGRL | Target domain Acc: {:.2f}".format(acc))
plt.savefig("./Results/src_003_tar_005.png", bbox_inches = 'tight')
