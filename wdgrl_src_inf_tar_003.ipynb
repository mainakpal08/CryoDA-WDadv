# %%
from __future__ import print_function
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from numpy.random import randint
import math
from torch.nn import functional as F
import numpy as np
import time
import pdb
from torch.autograd import grad
import copy
import shutil
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

import utils
import models

# %%
class opt:
    source_train_path = '/datasets/snrinfinity/SNRinfinity_train.h5'
    source_test_path = '/datasets/snrinfinity/SNRinfinity_test.h5'
    target_train_path = '/datasets/snr003/SNR003_train.h5'
    target_test_path = '/datasets/snr003/SNR003_test.h5'
    numclass = 10
    fet_size = 128
    h = 400
    nepoch = 100
    nepoch_wdgrl = 50
    cuda = True
    manualSeed = 9182
    batch_size = 32
    tomo_dim = (32,32,32)
    clfr_lr = 0.0001
    critic_iter = 1
    clfr_iter = 1
    gamma = 10
    wd_clf = 1
    save_src_clfr = "./best_model/source_clfr_snrinfinity.pt"
    save_tar_clfr = "./best_model/target_clfr_snr003_from_inf.pt"

# %%
if opt.manualSeed is None:
    opt.manualSeed = random.randint(1, 10000)
print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
if opt.cuda:
    torch.cuda.manual_seed_all(opt.manualSeed)

cudnn.benchmark = True

if torch.cuda.is_available() and not opt.cuda:
    print("WARNING: You have a CUDA device, so you should probably run with --cuda")
# Out:
# Random Seed:  9182

# %%
data = utils.DATA_LOADER(opt)
print("# of source training samples: ", data.source_ntrain)
print("# of source test samples: ", data.source_ntest)
print("# of target training samples: ", data.target_ntrain)
print("# of target test samples: ", data.target_ntest)
print("# of class: ", data.numclass)
# Out:
# # of source training samples:  4500
# # of source test samples:  500
# # of target training samples:  4500
# # of target test samples:  500
# # of class:  10

# %%
source_clsfr = models.CLFR(opt)
print(source_clsfr)
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
cls_criterion = nn.CrossEntropyLoss()
input_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])
input_label = torch.FloatTensor(opt.batch_size)

# %%
if opt.cuda :
    source_clsfr.cuda()
    cls_criterion.cuda()
    input_tomo = input_tomo.cuda()
    input_label = input_label.cuda()

# %%
def sample():
    batch_tomo, batch_label = data.source_next_batch(opt.batch_size)
    input_tomo.copy_(batch_tomo)
    input_label.copy_(batch_label)

# %%
optim_clfr = optim.Adam(source_clsfr.parameters(), lr=opt.clfr_lr)

# %%
def calculate_accuracy(net, tomo, label):
    utils.set_requires_grad(net, requires_grad=False)
    logits = net(tomo.cuda())
    _, predicted = torch.max(logits, 1)
    c = (predicted == label.cuda()).sum()
    c = c.cpu().numpy()
    acc = c / len(label)

    return acc

# %%
best_acc = 0

for epoch in range(opt.nepoch):
    for i in range(0, data.source_ntrain, opt.batch_size):

        for p in source_clsfr.parameters():
            p.requires_grad = True

        sample()
        source_clsfr.zero_grad()
        input_tomoV = Variable(input_tomo)
        input_labelV = Variable(input_label.long())

        logits = source_clsfr(input_tomoV)
        loss = cls_criterion(logits, input_labelV)
        loss.backward()
        optim_clfr.step()

    source_clsfr.eval()
    acc = calculate_accuracy(net=source_clsfr, tomo=data.source_test_subtom, label=data.source_test_label)
    print('[%d/%d] clfr_loss: %.4f | test_acc: %.4f'% (epoch, opt.nepoch, loss.item(),acc))

    if acc >= best_acc:
        print('[Source Domain]Validation Acc increased ({:.4f} --> {:.4f}).  Saving model ...'.format(best_acc,acc))
        torch.save(source_clsfr.state_dict(), opt.save_src_clfr)
        best_acc = acc

    source_clsfr.train()
# Out:
# [0/100] clfr_loss: 2.0386 | test_acc: 0.1140
# [Source Domain]Validation Acc increased (0.0000 --> 0.1140).  Saving model ...
# [1/100] clfr_loss: 1.6566 | test_acc: 0.3740
# [Source Domain]Validation Acc increased (0.1140 --> 0.3740).  Saving model ...
# [2/100] clfr_loss: 1.2298 | test_acc: 0.5340
# [Source Domain]Validation Acc increased (0.3740 --> 0.5340).  Saving model ...
# [3/100] clfr_loss: 1.1765 | test_acc: 0.7160
# [Source Domain]Validation Acc increased (0.5340 --> 0.7160).  Saving model ...
# [4/100] clfr_loss: 0.6631 | test_acc: 0.8120
# [Source Domain]Validation Acc increased (0.7160 --> 0.8120).  Saving model ...
# [5/100] clfr_loss: 0.5070 | test_acc: 0.8000
# [6/100] clfr_loss: 0.6339 | test_acc: 0.8180
# [Source Domain]Validation Acc increased (0.8120 --> 0.8180).  Saving model ...
# [7/100] clfr_loss: 0.3836 | test_acc: 0.8380
# [Source Domain]Validation Acc increased (0.8180 --> 0.8380).  Saving model ...
# [8/100] clfr_loss: 0.9346 | test_acc: 0.8400
# [Source Domain]Validation Acc increased (0.8380 --> 0.8400).  Saving model ...
# [9/100] clfr_loss: 0.3056 | test_acc: 0.8400
# [Source Domain]Validation Acc increased (0.8400 --> 0.8400).  Saving model ...
# [10/100] clfr_loss: 0.2394 | test_acc: 0.8140
# [11/100] clfr_loss: 0.2522 | test_acc: 0.8340
# [12/100] clfr_loss: 0.4254 | test_acc: 0.8460
# [Source Domain]Validation Acc increased (0.8400 --> 0.8460).  Saving model ...
# [13/100] clfr_loss: 0.1928 | test_acc: 0.8660
# [Source Domain]Validation Acc increased (0.8460 --> 0.8660).  Saving model ...
# [14/100] clfr_loss: 0.4438 | test_acc: 0.8480
# [15/100] clfr_loss: 0.0592 | test_acc: 0.8660
# [Source Domain]Validation Acc increased (0.8660 --> 0.8660).  Saving model ...
# [16/100] clfr_loss: 0.0510 | test_acc: 0.8720
# [Source Domain]Validation Acc increased (0.8660 --> 0.8720).  Saving model ...
# [17/100] clfr_loss: 0.0389 | test_acc: 0.8660
# [18/100] clfr_loss: 0.1295 | test_acc: 0.8520
# [19/100] clfr_loss: 0.1031 | test_acc: 0.8600
# [20/100] clfr_loss: 0.0224 | test_acc: 0.8640
# [21/100] clfr_loss: 0.1417 | test_acc: 0.8620
# [22/100] clfr_loss: 0.0423 | test_acc: 0.8800
# [Source Domain]Validation Acc increased (0.8720 --> 0.8800).  Saving model ...
# [23/100] clfr_loss: 0.0626 | test_acc: 0.8540
# [24/100] clfr_loss: 0.0481 | test_acc: 0.8760
# [25/100] clfr_loss: 0.1167 | test_acc: 0.8580
# [26/100] clfr_loss: 0.0515 | test_acc: 0.8660
# [27/100] clfr_loss: 0.0257 | test_acc: 0.8640
# [28/100] clfr_loss: 0.0075 | test_acc: 0.8680
# [29/100] clfr_loss: 0.0396 | test_acc: 0.8240
# [30/100] clfr_loss: 0.0012 | test_acc: 0.8740
# [31/100] clfr_loss: 0.0074 | test_acc: 0.8720
# [32/100] clfr_loss: 0.0035 | test_acc: 0.8580
# [33/100] clfr_loss: 0.0412 | test_acc: 0.8520
# [34/100] clfr_loss: 0.0093 | test_acc: 0.8440
# [35/100] clfr_loss: 0.0302 | test_acc: 0.8520
# [36/100] clfr_loss: 0.0452 | test_acc: 0.8520
# [37/100] clfr_loss: 0.0434 | test_acc: 0.8640
# [38/100] clfr_loss: 0.0338 | test_acc: 0.8640
# [39/100] clfr_loss: 0.0092 | test_acc: 0.8820
# [Source Domain]Validation Acc increased (0.8800 --> 0.8820).  Saving model ...
# [40/100] clfr_loss: 0.0042 | test_acc: 0.8560
# [41/100] clfr_loss: 0.0134 | test_acc: 0.8680
# [42/100] clfr_loss: 0.0013 | test_acc: 0.8540
# [43/100] clfr_loss: 0.0011 | test_acc: 0.8700
# [44/100] clfr_loss: 0.1844 | test_acc: 0.8540
# [45/100] clfr_loss: 0.0058 | test_acc: 0.8600
# [46/100] clfr_loss: 0.0313 | test_acc: 0.8520
# [47/100] clfr_loss: 0.0410 | test_acc: 0.8520
# [48/100] clfr_loss: 0.0003 | test_acc: 0.8680
# [49/100] clfr_loss: 0.0087 | test_acc: 0.8340
# [50/100] clfr_loss: 0.0063 | test_acc: 0.8680
# [51/100] clfr_loss: 0.0005 | test_acc: 0.8620
# [52/100] clfr_loss: 0.0069 | test_acc: 0.8560
# [53/100] clfr_loss: 0.0205 | test_acc: 0.8800
# [54/100] clfr_loss: 0.0005 | test_acc: 0.8720
# [55/100] clfr_loss: 0.2427 | test_acc: 0.8700
# [56/100] clfr_loss: 0.0049 | test_acc: 0.8660
# [57/100] clfr_loss: 0.0008 | test_acc: 0.8740
# [58/100] clfr_loss: 0.0010 | test_acc: 0.8520
# [59/100] clfr_loss: 0.0031 | test_acc: 0.8640
# [60/100] clfr_loss: 0.0023 | test_acc: 0.8760
# [61/100] clfr_loss: 0.0755 | test_acc: 0.8480
# [62/100] clfr_loss: 0.0087 | test_acc: 0.8720
# [63/100] clfr_loss: 0.0913 | test_acc: 0.8500
# [64/100] clfr_loss: 0.0023 | test_acc: 0.8780
# [65/100] clfr_loss: 0.0019 | test_acc: 0.8800
# [66/100] clfr_loss: 0.0209 | test_acc: 0.8260
# [67/100] clfr_loss: 0.0010 | test_acc: 0.8700
# [68/100] clfr_loss: 0.0002 | test_acc: 0.8780
# [69/100] clfr_loss: 0.0023 | test_acc: 0.8720
# [70/100] clfr_loss: 0.0178 | test_acc: 0.8160
# [71/100] clfr_loss: 0.0028 | test_acc: 0.8700
# [72/100] clfr_loss: 0.0050 | test_acc: 0.8600
# [73/100] clfr_loss: 0.0040 | test_acc: 0.8840
# [Source Domain]Validation Acc increased (0.8820 --> 0.8840).  Saving model ...
# [74/100] clfr_loss: 0.5074 | test_acc: 0.8480
# [75/100] clfr_loss: 0.0044 | test_acc: 0.8740
# [76/100] clfr_loss: 0.0006 | test_acc: 0.8680
# [77/100] clfr_loss: 0.0014 | test_acc: 0.8580
# [78/100] clfr_loss: 0.0008 | test_acc: 0.8660
# [79/100] clfr_loss: 0.0001 | test_acc: 0.8820
# [80/100] clfr_loss: 0.0118 | test_acc: 0.8780
# [81/100] clfr_loss: 0.0113 | test_acc: 0.8200
# [82/100] clfr_loss: 0.0052 | test_acc: 0.8840
# [Source Domain]Validation Acc increased (0.8840 --> 0.8840).  Saving model ...
# [83/100] clfr_loss: 0.0107 | test_acc: 0.8860
# [Source Domain]Validation Acc increased (0.8840 --> 0.8860).  Saving model ...
# [84/100] clfr_loss: 0.0054 | test_acc: 0.8700
# [85/100] clfr_loss: 0.0142 | test_acc: 0.8420
# [86/100] clfr_loss: 0.0018 | test_acc: 0.8560
# [87/100] clfr_loss: 0.0006 | test_acc: 0.8820
# [88/100] clfr_loss: 0.0011 | test_acc: 0.8520
# [89/100] clfr_loss: 0.0003 | test_acc: 0.8740
# [90/100] clfr_loss: 0.0070 | test_acc: 0.8580
# [91/100] clfr_loss: 0.0021 | test_acc: 0.8760
# [92/100] clfr_loss: 0.0000 | test_acc: 0.8700
# [93/100] clfr_loss: 0.0002 | test_acc: 0.8640
# [94/100] clfr_loss: 0.1418 | test_acc: 0.8440
# [95/100] clfr_loss: 0.0002 | test_acc: 0.8840
# [96/100] clfr_loss: 0.0023 | test_acc: 0.8640
# [97/100] clfr_loss: 0.0016 | test_acc: 0.8820
# [98/100] clfr_loss: 0.0001 | test_acc: 0.8820
# [99/100] clfr_loss: 0.0001 | test_acc: 0.8860
# [Source Domain]Validation Acc increased (0.8860 --> 0.8860).  Saving model ...

# %%
target_clsfr = models.CLFR(opt)
target_clsfr.load_state_dict(torch.load(opt.save_src_clfr))
# Out:
# <All keys matched successfully>

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def gradient_penalty(critic, h_s, h_t):
    # based on: https://github.com/caogang/wgan-gp/blob/master/gan_cifar10.py#L116
    alpha = torch.rand(h_s.size(0), 1).to(device)
    differences = h_t - h_s
    interpolates = h_s + (alpha * differences)
    interpolates = torch.stack([interpolates, h_s, h_t]).requires_grad_()

    preds = critic(interpolates)
    gradients = grad(preds, interpolates,
                     grad_outputs=torch.ones_like(preds),
                     retain_graph=True, create_graph=True)[0]
    gradient_norm = gradients.norm(2, dim=1)
    gradient_penalty = ((gradient_norm - 1)**2).mean()
    return gradient_penalty

# %%
critic = models.CRITIC(opt)
print(critic)
# Out:
# CRITIC(
#   (critic_block): Sequential(
#     (0): Linear(in_features=128, out_features=50, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
critic_optim = torch.optim.Adam(critic.parameters(), lr=1e-4)
clf_optim = torch.optim.Adam(target_clsfr.parameters(), lr=opt.clfr_lr)

# %%
clf_criterion = nn.CrossEntropyLoss()
source_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])
source_label = torch.FloatTensor(opt.batch_size)
target_tomo = torch.FloatTensor(opt.batch_size, opt.tomo_dim[0], opt.tomo_dim[1], opt.tomo_dim[2])

# %%
if opt.cuda :
    critic.cuda()
    target_clsfr.cuda()
    clf_criterion.cuda()
    source_tomo = source_tomo.cuda()
    source_label = source_label.cuda()
    target_tomo = target_tomo.cuda()

# %%
def both_sample():
    source_batch_tomo, source_batch_label = data.source_next_batch(opt.batch_size)
    source_tomo.copy_(source_batch_tomo)
    source_label.copy_(source_batch_label)
    target_batch_tomo, _ = data.target_next_batch(opt.batch_size)
    target_tomo.copy_(target_batch_tomo)

# %%
best_acc = 0

for epoch in range(opt.nepoch_wdgrl):
    for i in range(0, data.source_ntrain, opt.batch_size):
        both_sample()

        #train critic
        utils.set_requires_grad(critic, requires_grad=True)
        utils.set_requires_grad(target_clsfr, requires_grad=False)

        with torch.no_grad():
            h_s = target_clsfr.feature_extractor(source_tomo)
            h_t = target_clsfr.feature_extractor(target_tomo)
        
        for _ in range(opt.critic_iter):
            gp = gradient_penalty(critic, h_s, h_t)
            critic_s = critic(h_s)
            critic_t = critic(h_t)
            wasserstein_distance = critic_s.mean() - critic_t.mean()
            critic_cost = -wasserstein_distance + opt.gamma*gp

            critic_optim.zero_grad()
            critic_cost.backward()
            critic_optim.step()

        #train classifier
        utils.set_requires_grad(critic, requires_grad=False)
        utils.set_requires_grad(target_clsfr, requires_grad=True)

        for _ in range(opt.clfr_iter):
            source_features = target_clsfr.feature_extractor(source_tomo)
            target_features = target_clsfr.feature_extractor(target_tomo)

            source_preds = target_clsfr.classify(source_features)
            clf_loss = clf_criterion(source_preds, source_label.long())

            w_dist = critic(source_features).mean() - critic(target_features).mean()
            loss = clf_loss + opt.wd_clf*w_dist

            clf_optim.zero_grad()
            loss.backward()
            clf_optim.step()

    target_clsfr.eval()

    target_batch_tomo, target_batch_label = data.target_next_batch(100)
    tar_acc = calculate_accuracy(net=target_clsfr, tomo=target_batch_tomo, label=target_batch_label)

    print('[%d/%d] critic_cost: %.4f | w_dist: %.4f | clf_loss: %.4f | tar_acc: %.4f'% (epoch, opt.nepoch_wdgrl, critic_cost.item(), wasserstein_distance.item(), loss.item(), tar_acc))

    if tar_acc >= best_acc:
        print('[Target Domain]Validation Acc increased ({:.4f} --> {:.4f}).  Saving model ...'.format(best_acc,tar_acc))
        torch.save(target_clsfr.state_dict(), opt.save_tar_clfr)
        best_acc = tar_acc

    target_clsfr.train()
# Out:
# [0/50] critic_cost: 9.0959 | w_dist: -0.5891 | clf_loss: -0.3086 | tar_acc: 0.8700
# [Target Domain]Validation Acc increased (0.0000 --> 0.8700).  Saving model ...
# [1/50] critic_cost: 10.1325 | w_dist: -0.6966 | clf_loss: -0.6483 | tar_acc: 0.7000
# [2/50] critic_cost: 8.8538 | w_dist: 0.5136 | clf_loss: 0.5323 | tar_acc: 0.8600
# [3/50] critic_cost: 9.4677 | w_dist: -0.6046 | clf_loss: -0.5289 | tar_acc: 0.8100
# [4/50] critic_cost: 10.2533 | w_dist: -1.0517 | clf_loss: -0.4561 | tar_acc: 0.6900
# [5/50] critic_cost: 9.2970 | w_dist: -0.5613 | clf_loss: -0.2204 | tar_acc: 0.8800
# [Target Domain]Validation Acc increased (0.8700 --> 0.8800).  Saving model ...
# [6/50] critic_cost: 9.5822 | w_dist: -0.2442 | clf_loss: -0.0576 | tar_acc: 0.8000
# [7/50] critic_cost: 9.7932 | w_dist: -0.4183 | clf_loss: -0.1892 | tar_acc: 0.8500
# [8/50] critic_cost: 9.3922 | w_dist: -0.2101 | clf_loss: -0.0882 | tar_acc: 0.7500
# [9/50] critic_cost: 9.7937 | w_dist: -0.3738 | clf_loss: -0.3634 | tar_acc: 0.8100
# [10/50] critic_cost: 10.8539 | w_dist: -1.3361 | clf_loss: -0.9541 | tar_acc: 0.7600
# [11/50] critic_cost: 9.6056 | w_dist: -0.0162 | clf_loss: 0.0110 | tar_acc: 0.7600
# [12/50] critic_cost: 10.1862 | w_dist: -0.8109 | clf_loss: -0.6204 | tar_acc: 0.8400
# [13/50] critic_cost: 9.9379 | w_dist: -0.1751 | clf_loss: -0.1677 | tar_acc: 0.8500
# [14/50] critic_cost: 9.8191 | w_dist: -0.1365 | clf_loss: 0.3581 | tar_acc: 0.7700
# [15/50] critic_cost: 9.9672 | w_dist: -0.3866 | clf_loss: -0.2872 | tar_acc: 0.7800
# [16/50] critic_cost: 8.1178 | w_dist: 1.3313 | clf_loss: 1.9411 | tar_acc: 0.7500
# [17/50] critic_cost: 10.7677 | w_dist: -1.3254 | clf_loss: -0.7538 | tar_acc: 0.6700
# [18/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.2137 | tar_acc: 0.7500
# [19/50] critic_cost: 9.9193 | w_dist: 0.0389 | clf_loss: 0.0442 | tar_acc: 0.7600
# [20/50] critic_cost: 9.9212 | w_dist: 0.0113 | clf_loss: 0.0174 | tar_acc: 0.8400
# [21/50] critic_cost: 9.8067 | w_dist: 0.0628 | clf_loss: 0.0838 | tar_acc: 0.7700
# [22/50] critic_cost: 9.7707 | w_dist: 0.0025 | clf_loss: 0.0336 | tar_acc: 0.8200
# [23/50] critic_cost: 9.8932 | w_dist: -0.0979 | clf_loss: -0.0927 | tar_acc: 0.8000
# [24/50] critic_cost: 9.9181 | w_dist: 0.0128 | clf_loss: 0.0145 | tar_acc: 0.8300
# [25/50] critic_cost: 9.9105 | w_dist: -0.0213 | clf_loss: -0.0206 | tar_acc: 0.8200
# [26/50] critic_cost: 9.9605 | w_dist: 0.0102 | clf_loss: 0.0141 | tar_acc: 0.8000
# [27/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0665 | tar_acc: 0.8800
# [Target Domain]Validation Acc increased (0.8800 --> 0.8800).  Saving model ...
# [28/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0004 | tar_acc: 0.8200
# [29/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0238 | tar_acc: 0.8400
# [30/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0001 | tar_acc: 0.7800
# [31/50] critic_cost: 9.9764 | w_dist: -0.0035 | clf_loss: -0.0030 | tar_acc: 0.8700
# [32/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0004 | tar_acc: 0.8500
# [33/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0016 | tar_acc: 0.8300
# [34/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0000 | tar_acc: 0.8600
# [35/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0000 | tar_acc: 0.8300
# [36/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0005 | tar_acc: 0.9200
# [Target Domain]Validation Acc increased (0.8800 --> 0.9200).  Saving model ...
# [37/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0004 | tar_acc: 0.7500
# [38/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0000 | tar_acc: 0.8500
# [39/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0075 | tar_acc: 0.8200
# [40/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0977 | tar_acc: 0.8600
# [41/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0073 | tar_acc: 0.8300
# [42/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0195 | tar_acc: 0.7100
# [43/50] critic_cost: 9.9822 | w_dist: 0.0014 | clf_loss: 0.0017 | tar_acc: 0.7800
# [44/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0000 | tar_acc: 0.8900
# [45/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0605 | tar_acc: 0.8600
# [46/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0085 | tar_acc: 0.7400
# [47/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0007 | tar_acc: 0.8900
# [48/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.5412 | tar_acc: 0.8400
# [49/50] critic_cost: 10.0000 | w_dist: 0.0000 | clf_loss: 0.0013 | tar_acc: 0.8300

# %%
target_clsfr = models.CLFR(opt)
target_clsfr.load_state_dict(torch.load(opt.save_tar_clfr))
target_clsfr.cuda()
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
target_clsfr.eval()
# Out:
# CLFR(
#   (conv1): Sequential(
#     (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (conv4): Sequential(
#     (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv5): Sequential(
#     (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (hidden): Sequential(
#     (0): Linear(in_features=128, out_features=400, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (feature_extractor): Sequential(
#     (0): Adjust_channel()
#     (1): Sequential(
#       (0): Conv3d(1, 8, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv3d(8, 16, kernel_size=(5, 5, 5), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (5): Sequential(
#       (0): Conv3d(64, 128, kernel_size=(2, 2, 2), stride=(1, 1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Flatten()
#   )
#   (classify): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=128, out_features=400, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Linear(in_features=400, out_features=10, bias=True)
#   )
# )

# %%
utils.set_requires_grad(target_clsfr, requires_grad=False)
acc = calculate_accuracy(net=target_clsfr, tomo=data.target_train_subtom, label=data.target_train_label)
acc
# Out:
# 0.8364444444444444

# %%
utils.set_requires_grad(target_clsfr, requires_grad=False)
logits = target_clsfr(data.target_train_subtom.cuda())
_, predicted = torch.max(logits, 1)

# %%
ground_truth = data.target_train_label
pred = predicted.cpu().numpy()

# %%
conf_mat = confusion_matrix(ground_truth, pred)

# %%
tomo_class = ['1bxn', '1f1b', '1yg6', '2byu', '2h12', '2ldb', '3gl1', '3hhb', '4d4r', '6t3e']

# %%
df_cm = pd.DataFrame(conf_mat, index = [i for i in tomo_class],
                  columns = [i for i in tomo_class])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10},fmt="d", cmap="magma_r")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Target: SNR 0.03 | Source: SNR inf | WDGRL | Target domain Acc: {:.2f}".format(acc))
plt.savefig("./Results/src_inf_tar_003.png", bbox_inches = 'tight')
